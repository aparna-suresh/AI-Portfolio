# %%
import chromadb
from langchain_community.vectorstores import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.retrievers import BM25Retriever
from langchain_core.documents import Document

# %%
db_path = "data"
collection_name = "recipe_dataset"

# %%
model_name = "sentence-transformers/all-MiniLM-L12-v2"
embeddings = HuggingFaceEmbeddings(model_name=model_name,
                                   model_kwargs={'device': "cuda"},
                                   encode_kwargs={'normalize_embeddings': False})
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
client_settings = chromadb.config.Settings(
    anonymized_telemetry=False,
    is_persistent=True
)
client = chromadb.PersistentClient(path=db_path, settings=client_settings)
collections = client.list_collections()
collections
# Out:
# [Collection(name=recipe_dataset)]

# %%
collection = client.get_collection(name=collection_name)
collection.count()
# Out:
# 77000

# %%
results = collection.get(
    limit=2,
    include=["documents", "metadatas"] # 'embeddings' is optional and large
)
results
# Out:
# {'ids': ['e6d5a705-b785-45e5-a6b1-d84f98b3b507',
#   '1cc3d452-de16-4dc5-8c1f-32f5913e7ff0'],
#  'embeddings': None,
#  'documents': ['# Title: Butter Baked Rice (Oamc)\n### Ingredients:\n1. 1 cup long grain rice\n2. 1 teaspoon salt\n3. 1/3 cup butter\n4. 1 teaspoon garlic powder\n5. 2 cups chicken stock (or vegetable stock)\n6. 3 teaspoons parsley\n7. 1/4 cup slivered almonds (optional)\n### Directions: \n1. Measure rice and salt in a bowl and pour on boiling water just to cover. Let stand 30 minutes.\n2. Drain and rinse with cold water.\n3. Melt butter in a frying pan and add rice. Saute for 5 minutes, stirring often until most of the butter is absorbed.\n4. Transfer to a greased 1L casserole dish.\n5. Combine garlic powder and chicken stock and pour over rice. Cover and bake at 350 degrees for 45-60 minutes.\n6. Add parsley and fluff with a fork.\n7. Sprinkle with almonds and bake for an additional 5 minutes.\n8. Cool completely, label and freeze.\n9. To serve, thaw overnight and reheat.\n10. Garnish with additional parsley if desired.\n11. To save time, double or triple recipe and make 2 or 3 meals at once.',
#   '# Title: Vegan Orange Dream\n### Ingredients:\n1. 1 12 cups orange juice, chilled\n2. 1 cup light vanilla soymilk, chilled\n3. 13 cup silk tofu or 13 cup soft tofu\n4. 1 tablespoon dark honey\n5. 1 teaspoon grated orange zest\n6. 12 teaspoon vanilla extract\n7. 5 ice cubes\n8. 4 peeled orange sections\n### Directions: \n1. In a blender, combine everything except the orange segments.\n2. Blend until smooth and frothy, about 30 seconds.\n3. Pour into tall, chilled glasses and garnish with orange segments.'],
#  'uris': None,
#  'included': ['documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'is_gluten_free': 1,
#    'is_quick': 0,
#    'is_healthy': 0,
#    'category': 'Baking',
#    'is_air_fryer': 0,
#    'is_comfort_food': 1,
#    'is_dinner': 1,
#    'is_lunch': 0,
#    'is_light_food': 0,
#    'is_breakfast': 0,
#    'is_nut_free': 0,
#    'is_slow_cooker': 0,
#    'has_passive_time': 1,
#    'is_one_pot': 0,
#    'is_dairy_free': 0,
#    'is_hearty_food': 0,
#    'steps_counts': 11,
#    'title': 'Butter Baked Rice (Oamc)',
#    'is_no_oven': 0,
#    'is_spicy_food': 0,
#    'doc_id': 'recipe_0',
#    'ingredients': ['long grain rice',
#     'salt',
#     'butter',
#     'garlic',
#     'chicken stock',
#     'parsley',
#     'almonds']},
#   {'is_hearty_food': 0,
#    'is_no_oven': 1,
#    'is_slow_cooker': 0,
#    'is_lunch': 0,
#    'steps_counts': 3,
#    'is_healthy': 0,
#    'title': 'Vegan Orange Dream',
#    'is_air_fryer': 0,
#    'is_dinner': 0,
#    'is_comfort_food': 0,
#    'is_gluten_free': 1,
#    'is_spicy_food': 0,
#    'doc_id': 'recipe_1',
#    'is_breakfast': 0,
#    'is_nut_free': 1,
#    'is_one_pot': 0,
#    'is_light_food': 0,
#    'is_quick': 0,
#    'category': 'Baking',
#    'ingredients': ['orange juice',
#     'light vanilla soymilk',
#     'silk',
#     'honey',
#     'orange zest',
#     'vanilla',
#     'cubes',
#     'orange sections'],
#    'is_dairy_free': 0,
#    'has_passive_time': 1}]}

# %%
batch_size = 2000 
offset = 0
bm25_docs = []
total_docs = collection.count()
for i in range(0, total_docs, batch_size):
    batch = collection.get(
        include=["documents", "metadatas"],
        limit=batch_size,
        offset=offset
    )
    
    docs = batch["documents"]
    metadatas = batch["metadatas"]
    
    for doc, meta in zip(docs, metadatas):
        bm25_docs.append(Document(page_content=doc, metadata=meta))
        
    offset += batch_size
    print(f"Loaded {len(bm25_docs)} documents...")
# Out:
# Loaded 2000 documents...
# Loaded 4000 documents...
# Loaded 6000 documents...
# Loaded 8000 documents...
# Loaded 10000 documents...
# Loaded 12000 documents...
# Loaded 14000 documents...
# Loaded 16000 documents...
# Loaded 18000 documents...
# Loaded 20000 documents...
# Loaded 22000 documents...
# Loaded 24000 documents...
# Loaded 26000 documents...
# Loaded 28000 documents...
# Loaded 30000 documents...
# Loaded 32000 documents...
# Loaded 34000 documents...
# Loaded 36000 documents...
# Loaded 38000 documents...
# Loaded 40000 documents...
# Loaded 42000 documents...
# Loaded 44000 documents...
# Loaded 46000 documents...
# Loaded 48000 documents...
# Loaded 50000 documents...
# Loaded 52000 documents...
# Loaded 54000 documents...
# Loaded 56000 documents...
# Loaded 58000 documents...
# Loaded 60000 documents...
# Loaded 62000 documents...
# Loaded 64000 documents...
# Loaded 66000 documents...
# Loaded 68000 documents...
# Loaded 70000 documents...
# Loaded 72000 documents...
# Loaded 74000 documents...
# Loaded 76000 documents...
# Loaded 77000 documents...

# %%
bm25_retriever = BM25Retriever.from_documents(bm25_docs)

# %%
import pickle

index_path = "data/bm25_retriever.pkl"
with open(index_path, "wb") as f:
    pickle.dump(bm25_retriever, f)

# %%
vector_store = Chroma(
    collection_name = "recipe_dataset",
    embedding_function = embeddings,
    persist_directory="data",
    client_settings=client_settings,
)
# Out:
# C:\Users\sapar\AppData\Local\Temp\ipykernel_33124\2673258336.py:1: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   vector_store = Chroma(

# %%
bm25_retriever.k = 5
semantic_retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k":5})

# %%
from langchain_classic.retrievers import EnsembleRetriever

hybrid_retriever = EnsembleRetriever(
    retrievers = [semantic_retriever, bm25_retriever],
    weights = [0.6,0.4]
)

# %%
from sentence_transformers import CrossEncoder
re_rank_model =  CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
# Out:
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: cross-encoder/ms-marco-MiniLM-L-6-v2
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
def re_rank(query, query_result, check_score=True):
    # cross-encoder re-ranker
    docs = []
    for doc in query_result:
        docs.append(doc.page_content)
    ranks = re_rank_model.rank(query, docs)
    # print(f"ranks: {ranks}")
    if ranks[0]["score"] < 0:
        return [query_result[ranks[0]["corpus_id"]]]
    reranked_docs = []
    for rank_score in ranks:
        if check_score and rank_score["score"] < 0:
            continue
        else:
            reranked_docs.append(query_result[rank_score["corpus_id"]])
    return reranked_docs

# %%
def get_relevant_docs(query, should_re_rank=False):
    print(f"Query: {query}")
    query_result = hybrid_retriever.invoke(query)
    ids = []
    titles = []
    for doc in query_result:
        titles.append(doc.metadata['title'])
        ids.append(doc.metadata["doc_id"])
    print(f"initial Titles: {titles}")
    if should_re_rank:
        re_ranked_docs = re_rank(query, query_result)
    else:
        re_ranked_docs = query_result
    titles = []
    for doc in re_ranked_docs:
        titles.append(doc.metadata['title'])
    print(f"reranked title: {titles}")
    return {
        "doc_ids": ids,
        "relevant_documents": re_ranked_docs
    }

# %%
get_relevant_docs("How is corn used in Tamale bake recipe?", should_re_rank=True)
# Out:
# Query: How is corn used in Tamale bake recipe?
# initial Titles: ['Tamale Bake', 'Corn Bake', 'Corn Bake', 'Escalloped Corn', 'Escalloped Corn', 'Beef Tamale Bake', 'Fiesta Tamale Casserole', 'Noodle Salad', 'Tamale Joe', 'Scalloped Corn']
# reranked title: ['Tamale Bake', 'Beef Tamale Bake', 'Tamale Joe', 'Fiesta Tamale Casserole', 'Corn Bake']
# {'doc_ids': ['recipe_2398',
#   'recipe_2746',
#   'recipe_6589',
#   'recipe_47273',
#   'recipe_45579',
#   'recipe_119',
#   'recipe_39655',
#   'recipe_30699',
#   'recipe_39089',
#   'recipe_42654'],
#  'relevant_documents': [Document(metadata={'is_spicy_food': 1, 'steps_counts': 18, 'is_one_pot': 0, 'is_air_fryer': 0, 'is_light_food': 0, 'is_slow_cooker': 0, 'is_comfort_food': 1, 'is_breakfast': 1, 'is_healthy': 0, 'is_dairy_free': 0, 'ingredients': ['ground beef', 'onion', 'salt', 'chili powder', 'tomatoes', 'corn muffin', 'corn', 'olives', 'Cheddar cheese'], 'doc_id': 'recipe_2398', 'category': 'Baking', 'has_passive_time': 1, 'is_nut_free': 1, 'is_quick': 0, 'is_lunch': 0, 'is_no_oven': 0, 'title': 'Tamale Bake', 'is_dinner': 1, 'is_hearty_food': 1, 'is_gluten_free': 1}, page_content='# Title: Tamale Bake\n### Ingredients:\n1. 1 1/2 lb. ground beef\n2. 1 onion, chopped\n3. 1 tsp. salt\n4. 4 tsp. chili powder\n5. 2 c. canned tomatoes\n6. 1 pkg. Jiffy corn muffin mix\n7. 1 c. corn\n8. 1 can olives, sliced or chopped\n9. 1 c. Cheddar cheese\n### Directions: \n1. Brown beef\n2. and onions.\n3. Pour off fat.\n4. Add salt, chili powder and\n5. tomatoes.\n6. Cover\n7. and\n8. simmer for 20 minutes.\n9. Add corn and half\n10. of\n11. the olives.\n12. While meat simmers, make corn muffin mix as\n13. directed\n14. on\n15. package.\n16. Put\n17. meat mixture into casserole pan and top with prepared corn muffin mix.\n18. Bake at 350° for 1 hour. Sprinkle cheese and remaining olives on top.'),
#   Document(metadata={'is_spicy_food': 1, 'ingredients': ['ground beef', 'onion', 'jalapeno pepper', 'garlic', 'green chilies', 'enchilada sauce', 'corn kernels', 'muffin mix', 'cheese'], 'is_no_oven': 0, 'is_dairy_free': 0, 'is_gluten_free': 1, 'is_breakfast': 1, 'category': 'Baking', 'is_hearty_food': 1, 'is_nut_free': 1, 'is_healthy': 0, 'title': 'Beef Tamale Bake', 'has_passive_time': 1, 'is_dinner': 0, 'is_slow_cooker': 0, 'is_lunch': 0, 'is_one_pot': 0, 'is_light_food': 0, 'is_quick': 0, 'steps_counts': 7, 'is_air_fryer': 0, 'is_comfort_food': 1, 'doc_id': 'recipe_119'}, page_content='# Title: Beef Tamale Bake\n### Ingredients:\n1. 1 lb ground beef\n2. 1 cup chopped onion\n3. 14 cup chopped jalapeno pepper\n4. 2 tablespoons garlic powder\n5. 4 ounces of chopped green chilies\n6. 10 ounces enchilada sauce\n7. 15 ounces of whole corn kernels\n8. 8 12 ounces cornbread, muffin mix (follow mix directions or add 1/3 cup milk and 1 egg)\n9. 1 -2 cup of shredded cheese (I used Colby Jack)\n### Directions: \n1. Pre-heat oven 350 degrees.\n2. Brown the beef and drain the oil.\n3. Add onion, jalapenos, green chillis, garlic powder, enchilada sauce and corn kernals to beef.\n4. Spray baking pan and spoon meat mixture into pan.\n5. Mix up muffin mix with milk and egg.\n6. Spoon a layer over the meat mixture.\n7. Sprinkle cheese over top and bake for 30-40 minutes until cheese is baked over.'),
#   Document(metadata={'category': 'Mains', 'steps_counts': 7, 'is_no_oven': 0, 'is_nut_free': 1, 'has_passive_time': 0, 'is_lunch': 0, 'is_quick': 0, 'is_dinner': 1, 'is_dairy_free': 0, 'is_spicy_food': 1, 'title': 'Tamale Joe', 'is_breakfast': 0, 'is_one_pot': 1, 'is_light_food': 0, 'is_gluten_free': 1, 'is_healthy': 0, 'is_slow_cooker': 0, 'ingredients': ['ground beef', 'onion', 'chili powder', 'salt', 'milk', 'corn meal', 'pepper', 'corn', 'tomato sauce', 'olives', 'Cheddar cheese'], 'is_air_fryer': 0, 'is_comfort_food': 1, 'is_hearty_food': 1, 'doc_id': 'recipe_39089'}, page_content='# Title: Tamale Joe\n### Ingredients:\n1. 2 lb. ground beef\n2. 1 large onion, chopped\n3. 2 Tbsp. chili powder\n4. 2 tsp. salt\n5. 1 c. milk\n6. 1/2 c. corn meal\n7. 1/4 tsp. pepper\n8. 1 (12 oz.) can corn, drained\n9. 2 (8 oz.) cans tomato sauce\n10. 1 small can olives, sliced\n11. 1 c. grated Cheddar cheese\n### Directions: \n1. Saute meat and onion in a large skillet.\n2. Add seasonings, corn, tomato sauce and milk.\n3. Simmer about 20 minutes.\n4. Gradually stir in corn meal.\n5. Add olives; pour into a 3-quart casserole dish and top with cheese.\n6. Bake about 40 minutes at 350°.\n7. Serves 8.'),
#   Document(metadata={'is_hearty_food': 0, 'is_one_pot': 0, 'is_air_fryer': 0, 'is_spicy_food': 1, 'is_quick': 0, 'doc_id': 'recipe_39655', 'is_gluten_free': 1, 'is_light_food': 0, 'is_dinner': 1, 'is_dairy_free': 0, 'is_healthy': 0, 'is_slow_cooker': 0, 'is_breakfast': 0, 'category': 'Mains', 'is_nut_free': 1, 'is_comfort_food': 1, 'is_no_oven': 0, 'title': 'Fiesta Tamale Casserole', 'has_passive_time': 0, 'ingredients': ['tamales', 'favorite chili recipe', 'Cheddar cheese', 'corn chips'], 'is_lunch': 1, 'steps_counts': 4}, page_content='# Title: Fiesta Tamale Casserole\n### Ingredients:\n1. 2 large cans tamales\n2. 2 cans chili or favorite chili recipe\n3. 1 1/2 to 2 c. sharp Cheddar cheese\n4. crushed corn chips\n### Directions: \n1. Layer unwrapped tamales, corn chips, chili and grated Cheddar cheese in a 9 x 12-inch baking dish.\n2. Bake at 350° for 20 to 30 minutes, until bubbly.'),
#   Document(metadata={'category': 'Baking', 'has_passive_time': 0, 'is_nut_free': 1, 'is_one_pot': 0, 'steps_counts': 5, 'is_comfort_food': 1, 'is_dairy_free': 0, 'is_dinner': 0, 'is_hearty_food': 0, 'is_slow_cooker': 0, 'doc_id': 'recipe_2746', 'title': 'Corn Bake', 'is_healthy': 0, 'is_breakfast': 1, 'is_spicy_food': 1, 'is_lunch': 0, 'is_light_food': 0, 'ingredients': ['onion', 'green pepper', 'margarine', 'eggs', 'corn', 'whole kernel corn', 'corn muffin', 'sour cream', 'Cheddar cheese'], 'is_quick': 0, 'is_gluten_free': 1, 'is_no_oven': 0, 'is_air_fryer': 0}, page_content='# Title: Corn Bake\n### Ingredients:\n1. 1 medium onion\n2. 1/2 green pepper\n3. 1/2 c. margarine\n4. 3 eggs\n5. 1 c. creamed corn\n6. 1 c. whole kernel corn\n7. 1 box Jiffy corn muffin mix\n8. 1 c. sour cream\n9. 1 c. shredded Cheddar cheese\n### Directions: \n1. Saute together the onion, green pepper and margarine.\n2. Add the eggs, creamed corn, kernel corn and corn muffin mix.\n3. Pour into a 2-quart dish.\n4. Top with sour cream and shredded cheese.\n5. Bake at 350° for 45 minutes.')]}
