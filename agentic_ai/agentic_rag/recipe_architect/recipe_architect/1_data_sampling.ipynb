# %%
import ast

import pandas as pd

# %%
recipe_dataset = pd.read_csv("data/full_dataset.csv", index_col=0)
recipe_dataset.head()
# Out:
#                    title                                        ingredients  \
# 0    No-Bake Nut Cookies  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  Jewell Ball'S Chicken  ["1 small jar chipped beef, cut up", "4 boned ...
# 2            Creamy Corn  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3          Chicken Funny  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4   Reeses Cups(Candy)    ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                           directions  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
#
#                                                  NER
# 0  ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1  ["beef", "chicken breasts", "cream of mushroom...
# 2  ["frozen corn", "cream cheese", "butter", "gar...
# 3  ["chicken", "chicken gravy", "cream of mushroo...
# 4  ["peanut butter", "graham cracker crumbs", "bu...

# %%
len(recipe_dataset)
# Out:
# 2231142

# %%
recipe_dataset.drop(axis=1, labels=["link", "source"], inplace=True)

# %%
import re


# Based on categories from https://cookbooks.com/recipes-search.aspx?id=1&tag=grill
def get_category(row):
    # 1. Specific Dish Types (Check Title first)
    specific_categories = {
    "Soup": ["soup", "stew", "chowder"],
    "Grains and Pasta": ["pasta", "spaghetti", "fettuccine", "lasagna","noodle", "noodles", "ramen", "udon", "soba", "mein", "vermicelli", "pho"],
    "Breads": ["pastry", "bread", "loaf", "muffin", "rolls", "muffins", "biscuit", "scone", "shortbread", "cracker", "crackers", "pizza", "calzone"],   
    "Salads": ["salad", "slaw", "vinaigrette"],
    "Drinks": ["drink", "smoothie", "cocktail", "punch", "beverage", "tea", "sangria"],
    "Condiments and sides": ["sandwich", "burger", "slider", "wrap", "panini", 
                                  "sauce", "dressing", "gravy", "pesto", "glaze","relish",
                                  "dip", "spread", "hummus", "guacamole"],   
    }
    # 2. Broad Ingredient
    broad_categories = {
    "Sweet": ["dessert", "caramel", "frosting", "whipped cream", "marshmallow", "marshmallows", "chocolate", "condensed milk","cake", "cupcake", "cheesecake", "gateau", "pie", "tart", "cobbler", "galette", "candy", "fudge", "truffle", "toffee", "brittle", "pralines", "cookie", "biscotti", "macaron", "macaroon", "brownie", "blondie"],
    "Baking": ["bake", "yeast", "vanilla", "shortening", "souffle", "souffles"],    
    "Mains": ["chicken", "ham", "hamburger","hamburgers", "pork", "meat",  "lamb", "bacon", "beef", "turkey", "steak", "sausage", "grilled", "grill", "bbq", "barbecue", "skewers", "fish", "prawns", "prawn", "shrimp", "tuna", "salmon", "crab", "lobster", "scallops", "oyster", "oysters",
              "casserole", "gratin", "hotdish"],
    "Vegan": ["vegan", "tofu", "lentils", "tempeh", "lentil", "chickpea", "seitan"]
    }
    non_vegan = ["cheese", "cream", "milk", "cream cheese", "condensed milk", "chicken", "ham", "pork", "meat",  "lamb", "bacon", "beef", "turkey", "steak", "sausage","fish", "prawns", "prawn", "shrimp", "tuna", "salmon", "crab", "lobster", "scallops", "oyster", "oysters", "egg", "eggs", "butter", "honey", "frosting", "whipped cream", "gelatin", "candy", "marshmallow", 
                 "marshmallows", "hamburger","hamburgers", "cake"]
    
    pattern = re.compile(r'\b(' + '|'.join(map(re.escape, non_vegan)) + r')\b', flags=re.IGNORECASE)
    
    full_data = ""
    if not pattern.search(row["NER"]):
        return "Vegan"
    
    if isinstance(row["title"], str):
        title = row["title"].lower()
        for cat in specific_categories:
            keywords = specific_categories[cat]
            if any(keyword in title for keyword in keywords):
                return cat        
        full_data += row["title"]   
    
    full_data += " "
    full_data = (full_data + " " + row["NER"] + " " + row["ingredients"]).lower()
    
    for broad_cat in broad_categories:
        keywords = broad_categories[broad_cat]
        if any(keyword in full_data for keyword in keywords):
            return broad_cat
    return "Other"

recipe_dataset["category"] = recipe_dataset.apply(get_category, axis=1)

# %%
value_counts = recipe_dataset["category"].value_counts()
for category, count in value_counts.items():
    print(f"{category} === {count} === {(count/len(recipe_dataset) * 100):.2f}%")
# Out:
# Sweet === 551923 === 24.74%
# Vegan === 424420 === 19.02%
# Mains === 386566 === 17.33%
# Other === 173941 === 7.80%
# Breads === 170246 === 7.63%
# Condiments and sides === 150482 === 6.74%
# Salads === 100107 === 4.49%
# Baking === 99649 === 4.47%
# Soup === 84005 === 3.77%
# Grains and Pasta === 58802 === 2.64%
# Drinks === 31001 === 1.39%

# %%
recipe_dataset.loc[recipe_dataset["category"] == "Vegan"][30:40]
# Out:
#                         title  \
# 148         Chocolate "Stuff"
# 158  Eggplant Spaghetti Sauce
# 161           Cranberry Punch
# 197       Festive Fruit Salad
# 202              Fruit Medley
# 209     Leroy'S Heavenly Hash
# 214           Mistletoe Punch
# 224           Spaghetti Salad
# 233             Beer Biscuits
# 236           Twinkie Dessert
#
#                                            ingredients  \
# 148  ["1 large box instant chocolate pudding mix", ...
# 158  ["1/2 c. oil (I use olive oil, extra light)", ...
# 161  ["1 qt. cranberry juice", "1 qt. ginger ale", ...
# 197  ["1 (20 oz.) can pineapple chunks, drained (re...
# 202  ["3 Tbsp. tapioca", "1 c. water", "1/2 c. suga...
# 209  ["No. 2 can fruit cocktail", "4 bananas, cut u...
# 214  ["1 (6 oz.) can frozen lemonade concentrate, t...
# 224  ["1 lb. spaghetti", "3 cucumbers, diced", "4 t...
# 233  ["2 c. biscuit mix", "1 1/2 Tbsp. sugar", "6 o...
# 236  ["14 Twinkies", "1 large box strawberry jello"...
#
#                                             directions  \
# 148  ["Make pudding as directed on package, then ad...
# 158  ["Heat oil in large pot.", "Add all the vegeta...
# 161  ["Mix and put in punch bowl.", "Top with sherb...
# 197  ["Combine pineapple, oranges, grapes, strawber...
# 202  ["Allow tapioca, 1 cup water and sugar to stan...
# 209  ["Mix in a large bowl.", "Refrigerate and serv...
# 214  ["Combine all ingredients, except ginger ale a...
# 224  ["In a saucepan, cook spaghetti until tender."...
# 233  ["Dissolve sugar in beer and add to biscuit mi...
# 236  ["Line bottom of 13x9 pan with Twinkies.", "Mi...
#
#                                                    NER category
# 148  ["chocolate pudding", "vanilla wafers", "pecans"]    Vegan
# 158  ["oil", "eggplant", "onions", "cauliflower", "...    Vegan
# 161  ["cranberry juice", "ginger ale", "O", "boilin...    Vegan
# 197  ["pineapple", "mandarin oranges", "grapes", "m...    Vegan
# 202  ["tapioca", "water", "sugar", "water", "orange...    Vegan
# 209  ["No", "bananas", "marshmallows", "pecan piece...    Vegan
# 214  ["frozen lemonade concentrate", "orange juice ...    Vegan
# 224  ["spaghetti", "cucumbers", "tomatoes", "stalks...    Vegan
# 233              ["biscuit mix", "sugar", "warm beer"]    Vegan
# 236  ["Twinkies", "strawberry jello", "water", "fro...    Vegan

# %%
results = recipe_dataset[recipe_dataset["title"].str.contains(" Appetizer", case=False, na=False)]
print(results.shape)
results.head()
# Out:
# (4030, 5)
#                                    title  \
# 827                   Hot Tuna Appetizer
# 846   Party Pizza Appetizers(Makes 90)
# 1041          "Cholives" Puff Appetizers
# 2938        Taco Salad(Cold Appetizer)
# 3520                   Sausage Appetizer
#
#                                             ingredients  \
# 827   ["1 (7 oz.) can water-packed tuna, drained and...
# 846   ["1 lb. hot sausage, cooked, drained and crumb...
# 1041  ["stuffed olives", "1/4 c. soft butter", "5 oz...
# 2938  ["1 c. mayonnaise", "1 c. sour cream", "1 pkg....
# 3520  ["1 lb. ground chuck", "1 lb. sausage", "1 lb....
#
#                                              directions  \
# 827   ["In medium bowl, combine tuna, anchovies, gre...
# 846   ["Combine all ingredients, except biscuits.", ...
# 1041  ["Soften butter.", "Add cheese and blend well....
# 2938  ["Mix avocados with lemon juice to a spreading...
# 3520  ["Brown meat and drain. Add diced Velveeta; st...
#
#                                                     NER category
# 827   ["water", "anchovy", "green pepper", "pimento"...    Mains
# 846   ["hot sausage", "onion", "sharp cheese", "Parm...   Breads
# 1041  ["olives", "butter", "English cheese spread", ...    Other
# 2938  ["mayonnaise", "sour cream", "taco", "beans", ...   Salads
# 3520  ["ground chuck", "sausage", "Worcestershire sa...    Mains

# %%
recipe_sample_balanced = recipe_dataset.groupby("category", group_keys=False).apply(
    lambda x: x.sample(min(len(x), 7000), random_state=42).reset_index(drop=True)
)
recipe_sample_balanced.head()
# Out:
# C:\Users\sapar\AppData\Local\Temp\ipykernel_39804\319767720.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   recipe_sample_balanced = recipe_dataset.groupby("category", group_keys=False).apply(
#                       title  \
# 0  Butter Baked Rice (Oamc)
# 1        Vegan Orange Dream
# 2          Baked Lima Beans
# 3                 Stromboli
# 4               Baked Clams
#
#                                          ingredients  \
# 0  ["1 cup long grain rice", "1 teaspoon salt", "...
# 1  ["1 12 cups orange juice, chilled", "1 cup lig...
# 2  ["1 lb. large dried lima beans, soaked overnig...
# 3  ["3 c. flour", "1 pkg. dry yeast", "2 Tbsp. su...
# 4  ["3 pounds Littleneck clams", "1 cup cornmeal"...
#
#                                           directions  \
# 0  ["Measure rice and salt in a bowl and pour on ...
# 1  ["In a blender, combine everything except the ...
# 2  ["Soak beans overnight and rinse.", "Cover wit...
# 3  ["Combine 1 1/4 cups flour, yeast, sugar and s...
# 4  ["Preheat oven to 350 degrees F.", "Place clam...
#
#                                                  NER category
# 0  ["long grain rice", "salt", "butter", "garlic"...   Baking
# 1  ["orange juice", "light vanilla soymilk", "sil...   Baking
# 2  ["beans", "brown sugar", "dry mustard", "onion...   Baking
# 3  ["flour", "yeast", "sugar", "cooking oil", "sa...   Baking
# 4  ["Littleneck clams", "cornmeal", "salt", "brea...   Baking

# %%
print(recipe_sample_balanced["category"].value_counts())
# Out:
# category
# Baking                  7000
# Breads                  7000
# Condiments and sides    7000
# Drinks                  7000
# Grains and Pasta        7000
# Mains                   7000
# Other                   7000
# Salads                  7000
# Soup                    7000
# Sweet                   7000
# Vegan                   7000
# Name: count, dtype: int64

# %%
recipe_sample_balanced.to_csv("recipe_sample_balanced.csv")
